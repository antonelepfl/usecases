# %% [markdown]
# # Notebook Setup
#
# The *Cell Placement Hippocampus* notebook requires some specific setup, which is installed by executing the following cell. This needs to be done only once for the execution of the notebook.
#
# If the setup is done, please select the *Cell Placement Hippocampus* notebook in the Navigation panel on the left...

# %%
# !pip2 install -q -i https://bbpteam.epfl.ch/repository/devpi/simple brainbuilder==0.2.1.dev0
# !pip2 install -q -i https://bbpteam.epfl.ch/repository/devpi/simple voxcellview==2.1.3.dev0
# !pip2 install -q -i https://bbpteam.epfl.ch/repository/devpi/simple voxcell==1.5.1.dev0
# !pip2 install -q pynrrd
# !pip2 -q install --upgrade "hbp-service-client==1.0.0"
# IF YOU RUN OUTSIDE COLLAB INSTALL widgetsnbextension EXTENSIONS
# !jupyter nbextension install --py widgetsnbextension --user
# !jupyter nbextension enable --py widgetsnbextension --user
# !jupyter nbextension install --py voxcellview --user
# !jupyter nbextension enable --py voxcellview --user
