# %% [markdown]
# ## Setting up the working environment
# ### Installing required packages

# %%
! conda install -y -c bioconda biobb_io=="1.1.6"
! conda install -y -c bioconda biobb_model=="1.1.9"
! conda install -y -c bioconda biobb_md=="1.1.7"
! conda install -y -c bioconda biobb_analysis=="1.0.5"
! conda install -y -c bioconda biobb_chemistry=="1.0.8"
! conda install -y simpletraj=="0.5"
! conda install -y -c conda-forge nglview=="2.7.1"

# %%
! pip install --upgrade "hbp-service-client" 
! pip install python-magic
